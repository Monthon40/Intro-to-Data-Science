# %% [markdown]
# # Pracetice Data & String Manipulation

# %%
import pandas as pd
import numpy as np

weather = pd.read_csv('./datasets/weather.csv')
weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %% [markdown]
# Given the data in wehater.csv, answer the following questions.
#
# (1) What is the highest range of temperature per day.
#
#
# (2) From the available data of the whole year, do you think the first half of the month (day 1 to day 15) have average range more that the later half of the month?

# %%
weather_melt=pd.melt(weather, id_vars=['id','year','month','element'], var_name ='day', value_name='temp')
weather_tidy = weather_melt.pivot_table(index=['id','year','month','day'],columns='element',values='temp').reset_index()
weather_tidy['range']=weather_tidy['tmax']-weather_tidy['tmin']
column = weather_tidy['range']
max(column)
# Out:
# 19.599999999999998

# %%
variable_split = weather_tidy.day.str.split('d') # return a series
weather_tidy['date'] = variable_split.str.get(1)
weather_tidy['date'] = weather_tidy['date'].astype(int)
weather_tidy = weather_tidy.sort_values('date')
count1 = weather_tidy['date'].between(0, 16, inclusive=False).sum()
first_half = weather_tidy['range'].head(count1).mean()
count2 = weather_tidy['date'].between(15, 32, inclusive=False).sum()
second_half = weather_tidy['range'].tail(count2).mean()
print("First half: ", first_half)
print("Second half: ", second_half)
if(first_half>second_half):
    print("Mean range of first half of the month is more than the second half.")

else:
   print("Mean range of second half of the month is more than the first half.")
# Out:
# First half:  14.878947368421052
# Second half:  14.078571428571426
# Mean range of first half of the month is more than the second half.
# C:\Users\uSeR\AppData\Local\Temp/ipykernel_9816/4234108663.py:5: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   count1 = weather_tidy['date'].between(0, 16, inclusive=False).sum()
# C:\Users\uSeR\AppData\Local\Temp/ipykernel_9816/4234108663.py:7: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   count2 = weather_tidy['date'].between(15, 32, inclusive=False).sum()
